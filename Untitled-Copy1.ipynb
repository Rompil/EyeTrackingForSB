# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
left_eye = []
right_eye = []
with open('C:\\Users\\sberlab6\\PycharmProjects\\EyeTrackingForSB\\test.dat','r') as f:
    for line in f:
        t = ''.join([c for c in line if c not in '(),']).split()
        t = [float(f) for f in t]
        l, r = tuple(t[:2]),tuple(t[2:])
        left_eye.append(l)
        right_eye.append(r)

# %%
x, y = map(list, zip(*left_eye))

# %%
fig = plt.figure()
fig.set_size_inches(18.5, 15.5, forward=True)
ax1 = fig.add_subplot(211)
ax1.plot(*zip(*left_eye))

ax2 = fig.add_subplot(212)
ax2.plot(*zip(*right_eye))
plt.grid(color='r', linestyle='-', linewidth=2)
plt.savefig('left and right eyes.png')
plt.show()

# %%
x, y = map(list, zip(*left_eye))

# %%
minx = [min(x)]*len(x)
maxx = [max(x)]*len(x)
plt.plot(np.arange(len(x)), x)
plt.plot(np.arange(len(y)), y)
plt.plot(np.arange(len(x)), minx)
plt.plot(np.arange(len(x)), maxx)
plt.show()

# %%
type(x)
# Out:
# list

# %%
min(x)
# Out:
# '-10.0'

# %%
open()
# Out:
# <_io.TextIOWrapper name='C:\\Users\\sberlab6\\PycharmProjects\\EyeTrackingForSB\\test.dat' mode='r' encoding='cp1251'>
